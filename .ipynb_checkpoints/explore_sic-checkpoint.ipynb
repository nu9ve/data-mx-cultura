# %%
import requests
from bs4 import BeautifulSoup
import time
import glob
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
data_dir = '/Users/nu9ve/data/mexico/sic/'

# %%
res = requests.get('https://sic.gob.mx/datos.php')

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %%
recursos_urls = []
for recurso in soup.find_all("div", class_="recurso"):
    recursos_urls.append('https://sic.gob.mx{}'.format(recurso.find('a').get('href')))

# %%
recursos_urls
# Out:
# ['https://sic.gob.mx/datos.php?table=auditorio',
#  'https://sic.gob.mx/datos.php?table=rnbp',
#  'https://sic.gob.mx/datos.php?table=otra_bib',
#  'https://sic.gob.mx/datos.php?table=teatro',
#  'https://sic.gob.mx/datos.php?table=museo',
#  'https://sic.gob.mx/datos.php?table=libreria',
#  'https://sic.gob.mx/datos.php?table=casa_artesania',
#  'https://sic.gob.mx/datos.php?table=galeria',
#  'https://sic.gob.mx/datos.php?table=universidad',
#  'https://sic.gob.mx/datos.php?table=centro_cultural',
#  'https://sic.gob.mx/datos.php?table=centro_desarrollo_indigena',
#  'https://sic.gob.mx/datos.php?table=comp_cine',
#  'https://sic.gob.mx/datos.php?table=fototeca',
#  'https://sic.gob.mx/datos.php?table=fonoteca',
#  'https://sic.gob.mx/datos.php?table=catedral',
#  'https://sic.gob.mx/datos.php?table=patrimonio_humanidad',
#  'https://sic.gob.mx/datos.php?table=zona_arqueologica',
#  'https://sic.gob.mx/datos.php?table=fnme',
#  'https://sic.gob.mx/datos.php?table=otra_declaratoria',
#  'https://sic.gob.mx/datos.php?table=frpintangible',
#  'https://sic.gob.mx/datos.php?table=centro_educacion',
#  'https://sic.gob.mx/datos.php?table=centro_investigacion_artistica',
#  'https://sic.gob.mx/datos.php?table=educacion_artistica',
#  'https://sic.gob.mx/datos.php?table=festival',
#  'https://sic.gob.mx/datos.php?table=festividad',
#  'https://sic.gob.mx/datos.php?table=feria_libro',
#  'https://sic.gob.mx/datos.php?table=convocatoria',
#  'https://sic.gob.mx/datos.php?table=discografica_dgcpi',
#  'https://sic.gob.mx/datos.php?table=publicacion_dgcpi',
#  'https://sic.gob.mx/datos.php?table=grupo_etnico',
#  'https://sic.gob.mx/datos.php?table=impresos',
#  'https://sic.gob.mx/datos.php?table=radi',
#  'https://sic.gob.mx/datos.php?table=revista',
#  'https://sic.gob.mx/datos.php?table=revista_elec',
#  'https://sic.gob.mx/datos.php?table=fondo_editorial',
#  'https://sic.gob.mx/datos.php?table=editorial',
#  'https://sic.gob.mx/datos.php?table=institucion_cultural',
#  'https://sic.gob.mx/datos.php?table=institucion_cultural_mun']

# %%
res_rec = requests.get(recursos_urls[1])

# %%
soup_rec = BeautifulSoup(res_rec.text, 'html.parser')

# %%
for download_link in soup_rec.find_all('div', class_='formato_csv'):
    print(download_link.find('a').get('href'))
# Out:
# //sic.gob.mx/opendata/d/0_biblioteca_directorio.csv

# %%
def download_file(url):
    local_filename = data_dir + url.split('/')[-1]
    # NOTE the stream=True parameter below
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(local_filename, 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192): 
                # If you have chunk encoded response uncomment if
                # and set chunk_size parameter to None.
                #if chunk: 
                f.write(chunk)
    return local_filename

# %%
for download_link in soup_rec.find_all('div', class_='formato_csv'):
    file = download_file('https:{}'.format(download_link.find('a').get('href')))
    print(file)
# Out:
# /Users/nu9ve/data/mexico/sic/0_biblioteca_directorio.csv

# %%
for recurso_url in recursos_urls:
    res_rec = requests.get(recurso_url)
    soup_rec = BeautifulSoup(res_rec.text, 'html.parser')
    for download_link in soup_rec.find_all('div', class_='formato_csv'):
        print('downloading {}'.format(download_link.find('a').get('href')))
        file = download_file('https:{}'.format(download_link.find('a').get('href')))
        print(file)
        time.sleep(1)
    time.sleep(0.5)
# Out:
# downloading //sic.gob.mx/opendata/d/0_auditorio_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_auditorio_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_biblioteca_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_biblioteca_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_otra_bib_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_otra_bib_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_teatro_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_teatro_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_museo_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_museo_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_museo_analitico.csv
# /Users/nu9ve/data/mexico/sic/0_museo_analitico.csv
# downloading //sic.gob.mx/opendata/d/0_libreria_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_libreria_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_casa_artesania_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_casa_artesania_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_galeria_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_galeria_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_universidad_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_universidad_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_centro_cultural_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_centro_cultural_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_centro_desarrollo_indigena_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_centro_desarrollo_indigena_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_comp_cine_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_comp_cine_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_fototeca_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_fototeca_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_fonoteca_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_fonoteca_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_catedral_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_catedral_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_patrimonio_humanidad_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_patrimonio_humanidad_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_zona_arqueologica_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_zona_arqueologica_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_fnme_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_fnme_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_otra_declaratoria_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_otra_declaratoria_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_frpintangible_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_frpintangible_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_centro_educacion_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_centro_educacion_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_centro_investigacion_artistica_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_centro_investigacion_artistica_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_educacion_artistica_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_educacion_artistica_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_festival_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_festival_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_festividad_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_festividad_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_feria_libro_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_feria_libro_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_convocatoria_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_convocatoria_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_discografica_dgcpi_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_discografica_dgcpi_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_publicacion_dgcpi_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_publicacion_dgcpi_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_grupo_etnico_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_grupo_etnico_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_impresos_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_impresos_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_radi_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_radi_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_revista_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_revista_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_revista_elec_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_revista_elec_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_fondo_editorial_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_fondo_editorial_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_editorial_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_editorial_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_institucion_cultural_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_institucion_cultural_directorio.csv
# downloading //sic.gob.mx/opendata/d/0_institucion_cultural_mun_directorio.csv
# /Users/nu9ve/data/mexico/sic/0_institucion_cultural_mun_directorio.csv

# %% [markdown]
# ## browse files

# %%
all_dfs = []
all_paths = glob.glob("%s*.csv" % (data_dir))
all_fns = []
for csv_path in all_paths:
    sic_df = pd.read_csv(csv_path, encoding = "ISO-8859-1")
    print(csv_path.split('/')[-1])
    print(sic_df.columns)
    print(sic_df.shape)
    print()
    all_dfs.append(sic_df)
    all_fns.append(csv_path.split('/')[-1])
# Out:
# 0_casa_artesania_directorio.csv
# Index(['casa_artesania_id', 'casa_artesania_nombre',
#        'casa_artesania_adscripcion', 'estado_id', 'nom_ent', 'municipio_id',
#        'nom_mun', 'localidad_id', 'nom_loc', 'casa_artesania_calle_numero',
#        'casa_artesania_colonia', 'casa_artesania_cp',
#        'casa_artesania_telfono1', 'casa_artesania_pagina_web', 'email',
#        'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (179, 19)
#
# 0_patrimonio_humanidad_directorio.csv
# Index(['patrimonio_humanidad_id', 'patrimonio_humanidad_nombre',
#        'patrimonio_humanidad_ano_inscripcion', 'estado_id', 'nom_ent',
#        'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'patrimonio_humanidad_pagina_web', 'gmaps_longitud', 'gmaps_latitud',
#        'link_sic', 'fecha_mod'],
#       dtype='object')
# (36, 14)
#
# 0_centro_educacion_directorio.csv
# Index(['centro_educacion_id', 'centro_educacion_nombre',
#        'centro_educacion_adscripcion', 'estado_id', 'nom_ent', 'municipio_id',
#        'nom_mun', 'localidad_id', 'nom_loc', 'centro_educacion_calle_numero',
#        'centro_educacion_colonia', 'centro_educacion_cp',
#        'centro_educacion_telfono1', 'pagina_web', 'email', 'gmaps_longitud',
#        'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (869, 19)
#
# 0_publicacion_dgcpi_directorio.csv
# Index(['publicacion_dgcpi_id', 'publicacion_dgcpi_titulo',
#        'publicacion_dgcpi_fecha_edicion', 'estado_id', 'nom_ent',
#        'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'publicacion_dgcpi_calle_numero', 'publicacion_dgcpi_colonia',
#        'publicacion_dgcpi_cp', 'publicacion_dgcpi_telfono1',
#        'publicacion_dgcpi_pagina_web', 'email', 'gmaps_longitud',
#        'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (191, 19)
#
# 0_grupo_etnico_directorio.csv
# Index(['grupo_etnico_id', 'grupo_etnico_nombre', 'grupo_etnico_presentacion',
#        'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id',
#        'nom_loc', 'grupo_etnico_calle_numero', 'grupo_etnico_colonia',
#        'grupo_etnico_cp', 'grupo_etnico_telfono1', 'grupo_etnico_pagina_web',
#        'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (69, 18)
#
# 0_institucion_cultural_mun_directorio.csv
# Index(['institucion_cultural_mun_id', 'institucion_cultural_mun_nombre',
#        'fecha_fundacion', 'institucion_cultural_mun_adscripcion', 'estado_id',
#        'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'institucion_cultural_mun_calle_numero',
#        'institucion_cultural_mun_colonia', 'institucion_cultural_mun_cp',
#        'institucion_cultural_mun_telfono1', 'pagina_web', 'pagina_web2',
#        'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (546, 21)
#
# 0_fonoteca_directorio.csv
# Index(['fonoteca_id', 'fonoteca_nombre', 'fonoteca_adscripcion', 'estado_id',
#        'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'fonoteca_calle_numero', 'fonoteca_colonia', 'fonoteca_cp',
#        'fonoteca_telfono1', 'fonoteca_pagina_web', 'email', 'gmaps_longitud',
#        'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (23, 19)
#
# 0_fondo_editorial_directorio.csv
# Index(['fondo_editorial_id', 'fondo_editorial_titulo',
#        'fondo_editorial_anno_edicion', 'fondo_editorial_autor_nombre',
#        'fondo_editorial_autor_ap_pa', 'fondo_editorial_autor_ap_ma',
#        'fondo_editorial_calle_numero', 'fondo_editorial_colonia',
#        'fondo_editorial_cp', 'fondo_editorial_telfono1', 'email', 'link_sic',
#        'fecha_mod'],
#       dtype='object')
# (6132, 13)
#
# 0_zona_arqueologica_directorio.csv
# Index(['zona_arqueologica_id', 'zona_arqueologica_nombre', 'estado_id',
#        'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'zona_arqueologica_calle_numero', 'zona_arqueologica_colonia',
#        'zona_arqueologica_cp', 'zona_arqueologica_telefono1', 'pagina_web',
#        'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (179, 18)
#
# 0_galeria_directorio.csv
# Index(['galeria_id', 'galeria_nombre', 'galeria_fecha_fundacion',
#        'galeria_adscripcion', 'estado_id', 'nom_ent', 'municipio_id',
#        'nom_mun', 'localidad_id', 'nom_loc', 'galeria_calle_numero',
#        'galeria_colonia', 'galeria_cp', 'galeria_telfono1',
#        'galeria_pagina_web', 'email', 'gmaps_longitud', 'gmaps_latitud',
#        'link_sic', 'fecha_mod'],
#       dtype='object')
# (941, 20)
#
# 0_teatro_directorio.csv
# Index(['teatro_id', 'teatro_nombre', 'teatro_fecha_fundacion',
#        'teatro_adscripcion', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun',
#        'localidad_id', 'nom_loc', 'teatro_calle_numero', 'teatro_colonia',
#        'teatro_cp', 'teatro_telefono1', 'pagina_web', 'email',
#        'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (725, 20)
#
# 0_centro_investigacion_artistica_directorio.csv
# Index(['centro_investigacion_artistica_id',
#        'centro_investigacion_artistica_nombre',
#        'centro_investigacion_artistica_adscripcion', 'estado_id', 'nom_ent',
#        'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'centro_investigacion_artistica_calle_numero',
#        'centro_investigacion_artistica_colonia',
#        'centro_investigacion_artistica_cp',
#        'centro_investigacion_artistica_telfono1',
#        'centro_investigacion_artistica_pagina_web', 'email', 'gmaps_longitud',
#        'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (71, 19)
#
# 0_radi_directorio.csv
# Index(['radi_id', 'radi_nombre', 'radi_siglas', 'radi_frecuencia',
#        'radi_potencia', 'radi_fecha_fundacion', 'radi_adscripcion',
#        'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id',
#        'nom_loc', 'radi_calle_numero', 'radi_colonia', 'radi_cp',
#        'radi_telfono1', 'pagina_web', 'pagina_web2', 'radi_podcast', 'email',
#        'email2', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (24, 24)
#
# 0_institucion_cultural_directorio.csv
# Index(['institucion_cultural_id', 'institucion_cultural_nombre',
#        'institucion_cultural_fecha_fundacion',
#        'institucion_cultural_adscripcion', 'estado_id', 'nom_ent',
#        'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'institucion_cultural_calle_numero', 'institucion_cultural_colonia',
#        'institucion_cultural_cp', 'institucion_cultural_telfono1',
#        'institucion_cultural_pagina_web', 'email', 'gmaps_longitud',
#        'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (32, 20)
#
# 0_museo_directorio.csv
# Index(['museo_id', 'museo_nombre', 'museo_tematica_n1',
#        'museo_fecha_fundacion', 'museo_adscripcion', 'estado_id', 'nom_ent',
#        'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'museo_calle_numero', 'museo_colonia', 'museo_cp', 'museo_telefono1',
#        'pagina_web', 'pagina_web2', 'email', 'twitter', 'gmaps_longitud',
#        'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (1426, 23)
#
# 0_centro_desarrollo_indigena_directorio.csv
# Index(['centro_desarrollo_indigena_id', 'centro_desarrollo_indigena_nombre',
#        'centro_desarrollo_indigena_adscripcion', 'estado_id', 'nom_ent',
#        'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'centro_desarrollo_indigena_calle_numero',
#        'centro_desarrollo_indigena_colonia', 'centro_desarrollo_indigena_cp',
#        'centro_desarrollo_indigena_telfono1',
#        'centro_desarrollo_indigena_pagina_web', 'email', 'gmaps_longitud',
#        'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (128, 19)
#
# 0_fototeca_directorio.csv
# Index(['fototeca_id', 'fototeca_nombre', 'fototeca_adscripcion', 'estado_id',
#        'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'fototeca_calle_numero', 'fototeca_colonia', 'fototeca_cp',
#        'fototeca_telfono1', 'fototeca_pagina_web', 'email', 'gmaps_longitud',
#        'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (102, 19)
#
# 0_revista_directorio.csv
# Index(['revista_id', 'revista_nombre', 'revista_fecha_fundacion',
#        'revista_adscripcion', 'revista_disciplina', 'revista_clasificacion',
#        'revista_periodicidad', 'estado_id', 'nom_ent', 'municipio_id',
#        'nom_mun', 'localidad_id', 'nom_loc', 'revista_calle_numero',
#        'revista_colonia', 'revista_cp', 'revista_telfono1', 'pagina_web',
#        'pagina_web2', 'email', 'email2', 'twitter', 'revista_issn', 'link_sic',
#        'fecha_mod'],
#       dtype='object')
# (284, 25)
#
# 0_festividad_directorio.csv
# Index(['festividad_id', 'festividad_nombre', 'estado_id', 'nom_ent',
#        'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'festividad_calle_numero', 'festividad_colonia', 'festividad_cp',
#        'festividad_telfono1', 'festividad_pagina_web', 'email',
#        'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (1251, 18)
#
# 0_centro_cultural_directorio.csv
# Index(['centro_cultural_id', 'centro_cultural_nombre',
#        'centro_cultural_fecha_fundacion', 'centro_cultural_adscripcion',
#        'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id',
#        'nom_loc', 'centro_cultural_calle_numero', 'centro_cultural_colonia',
#        'centro_cultural_cp', 'centro_cultural_telfono1',
#        'centro_cultural_pagina_web', 'email', 'gmaps_longitud',
#        'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (2067, 20)
#
# 0_frpintangible_directorio.csv
# Index(['frpintangible_id', 'frpintangible_nombre', 'frpintangible_fechadec',
#        'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id',
#        'nom_loc', 'frpintangible_calle_numero', 'frpintangible_colonia',
#        'frpintangible_cp', 'frpintangible_telfono1',
#        'frpintangible_pagina_web', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (318, 16)
#
# 0_convocatoria_directorio.csv
# Index(['convocatoria_id', 'nom_ent', 'nom_mun', 'convocatoria_nombre',
#        'convocatoria_disciplina', 'convocatoria_genero',
#        'convocatoria_convocan', 'convocatoria_bases', 'convocatoria_premios',
#        'convocatoria_fecha_fin', 'pagina_web', 'email', 'link_sic',
#        'fecha_mod'],
#       dtype='object')
# (488, 14)
#
# 0_festival_directorio.csv
# Index(['festival_id', 'festival_nombre', 'festival_disciplina',
#        'festival_sede', 'festival_primera_emision', 'festival_fecha_inicio',
#        'festival_fecha_fin', 'festival_telfono1', 'festival_telfono2',
#        'festival_fax', 'pagina_web', 'email',
#        'festival_institucion_informate1_pagina_web',
#        'festival_institucion_informate2_pagina_web', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (645, 16)
#
# 0_educacion_artistica_directorio.csv
# Index(['educacion_artistica_id', 'educacion_artistica_nombre',
#        'educacion_artistica_regimen', 'estado_id', 'nom_ent', 'municipio_id',
#        'nom_mun', 'localidad_id', 'nom_loc',
#        'educacion_artistica_calle_numero', 'educacion_artistica_colonia',
#        'educacion_artistica_cp', 'educacion_artistica_telfono1', 'email',
#        'pagina_web', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (1321, 17)
#
# 0_biblioteca_directorio.csv
# Index(['biblioteca_id', 'biblioteca_numero_coleccion', 'biblioteca_nombre',
#        'biblioteca_fecha_fundacion', 'biblioteca_adscripcion', 'estado_id',
#        'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'biblioteca_calle_numero', 'biblioteca_colonia', 'biblioteca_cp',
#        'biblioteca_telfono1', 'biblioteca_pagina_web', 'gmaps_longitud',
#        'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (7465, 20)
#
# 0_libreria_directorio.csv
# Index(['libreria_id', 'libreria_nombre', 'libreria_fecha_fundacion',
#        'libreria_adscripcion', 'estado_id', 'nom_ent', 'municipio_id',
#        'nom_mun', 'localidad_id', 'nom_loc', 'libreria_calle_numero',
#        'libreria_colonia', 'libreria_cp', 'libreria_telefono1',
#        'libreria_pagina_web', 'email', 'gmaps_longitud', 'gmaps_latitud',
#        'link_sic', 'fecha_mod'],
#       dtype='object')
# (1644, 20)
#
# 0_otra_declaratoria_directorio.csv
# Index(['otra_declaratoria_id', 'otra_declaratoria_nombre',
#        'otra_declaratoria_ano_inscripcion', 'estado_id', 'nom_ent',
#        'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'otra_declaratoria_calle_numero', 'otra_declaratoria_colonia',
#        'otra_declaratoria_cp', 'otra_declaratoria_telfono1',
#        'otra_declaratoria_pagina_web', 'gmaps_longitud', 'gmaps_latitud',
#        'link_sic', 'fecha_mod'],
#       dtype='object')
# (125, 18)
# 0_universidad_directorio.csv
# Index(['universidad_id', 'universidad_nombre', 'universidad_fecha_fundacion',
#        'universidad_adscripcion', 'estado_id', 'nom_ent', 'municipio_id',
#        'nom_mun', 'localidad_id', 'nom_loc', 'universidad_calle_numero',
#        'universidad_colonia', 'universidad_cp', 'universidad_telfono1',
#        'universidad_pagina_web', 'email', 'gmaps_longitud', 'gmaps_latitud',
#        'link_sic', 'fecha_mod'],
#       dtype='object')
# (3086, 20)
#
# 0_catedral_directorio.csv
# Index(['catedral_id', 'catedral_nombre', 'estado_id', 'nom_ent',
#        'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'catedral_calle_numero', 'catedral_colonia', 'catedral_cp',
#        'catedral_telfono1', 'catedral_pagina_web', 'email', 'gmaps_longitud',
#        'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (81, 18)
#
# 0_revista_elec_directorio.csv
# Index(['revista_elec_id', 'revista_elec_nombre',
#        'revista_elec_fecha_fundacion', 'revista_elec_adscripcion',
#        'revista_elec_clasificacion', 'estado_id', 'nom_ent', 'municipio_id',
#        'nom_mun', 'localidad_id', 'nom_loc', 'revista_elec_calle_numero',
#        'revista_elec_colonia', 'revista_elec_cp', 'revista_elec_telfono1',
#        'pagina_web', 'pagina_web2', 'email', 'email2', 'twitter', 'link_sic',
#        'fecha_mod'],
#       dtype='object')
# (148, 22)
#
# 0_auditorio_directorio.csv
# Index(['auditorio_id', 'auditorio_nombre', 'auditorio_fecha_fundacion',
#        'auditorio_adscripcion', 'estado_id', 'nom_ent', 'municipio_id',
#        'nom_mun', 'localidad_id', 'nom_loc', 'auditorio_calle_numero',
#        'auditorio_colonia', 'auditorio_cp', 'auditorio_telfono1',
#        'auditorio_pagina_web', 'gmaps_longitud', 'gmaps_latitud', 'link_sic',
#        'fecha_mod'],
#       dtype='object')
# (989, 19)
#
# 0_fnme_directorio.csv
# Index(['fnme_id', 'fnme_nombre', 'fnme_fecha2', 'estado_id', 'nom_ent',
#        'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'fnme_calle_numero', 'fnme_colonia', 'fnme_cp', 'fnme_telfono1',
#        'fnme_pagina_web', 'gmaps_longitud', 'gmaps_latitud', 'link_sic',
#        'fecha_mod'],
#       dtype='object')
# (500, 18)
#
# 0_otra_bib_directorio.csv
# Index(['otra_bib_id', 'otra_bib_nombre', 'otra_bib_fecha_fundacion',
#        'otra_bib_adscripcion', 'estado_id', 'nom_ent', 'municipio_id',
#        'nom_mun', 'localidad_id', 'nom_loc', 'otra_bib_calle_numero',
#        'otra_bib_colonia', 'otra_bib_cp', 'otra_bib_telfono1',
#        'otra_bib_pagina_web', 'gmaps_longitud', 'gmaps_latitud', 'link_sic',
#        'fecha_mod'],
#       dtype='object')
# (1868, 19)
#
# 0_discografica_dgcpi_directorio.csv
# Index(['discografica_dgcpi_id', 'discografica_dgcpi_titulo',
#        'discografica_dgcpi_anno_edicion', 'discografica_dgcpi_descripcion',
#        'discografica_dgcpi_artista', 'estado_id', 'nom_ent', 'municipio_id',
#        'nom_mun', 'localidad_id', 'nom_loc', 'discografica_dgcpi_produccion',
#        'discografica_dgcpi_temas', 'email', 'gmaps_longitud', 'gmaps_latitud',
#        'link_sic', 'fecha_mod'],
#       dtype='object')
# (173, 18)
#
# 0_editorial_directorio.csv
# Index(['editorial_id', 'editorial_nombre', 'editorial_fecha_fundacion',
#        'editorial_adscripcion', 'estado_id', 'nom_ent', 'municipio_id',
#        'nom_mun', 'localidad_id', 'nom_loc', 'editorial_calle_numero',
#        'editorial_colonia', 'editorial_cp', 'editorial_telfono1', 'pagina_web',
#        'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (414, 20)
#
# 0_feria_libro_directorio.csv
# Index(['feria_libro_id', 'feria_libro_nombre', 'estado_id', 'nom_ent',
#        'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'feria_libro_calle_numero', 'feria_libro_colonia', 'feria_libro_cp',
#        'feria_libro_telfono1', 'feria_libro_pagina_web', 'email',
#        'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (162, 18)
#
# 0_museo_analitico.csv
# Index(['estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id',
#        'nom_loc', 'cantidad_museos', 'pobtot', 'habxm', 'habxm2', 'habxm3',
#        'museo_por', 'fecha_calculo'],
#       dtype='object')
# (1287, 13)
#
# 0_impresos_directorio.csv
# Index(['impresos_id', 'impresos_nombre', 'impresos_fecha_fundacion',
#        'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id',
#        'nom_loc', 'impresos_calle_numero', 'impresos_colonia', 'impresos_cp',
#        'impresos_telfono1', 'impresos_pagina_web', 'email', 'gmaps_longitud',
#        'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (326, 19)
#
# 0_comp_cine_directorio.csv
# Index(['comp_cine_id', 'comp_cine_nombre', 'comp_cine_fecha_fundacion',
#        'comp_cine_adscripcion', 'comp_cine_npantallas', 'estado_id', 'nom_ent',
#        'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc',
#        'comp_cine_calle_numero', 'comp_cine_colonia', 'comp_cine_cp',
#        'comp_cine_telfono1', 'comp_cine_pagina_web', 'gmaps_longitud',
#        'gmaps_latitud', 'link_sic', 'fecha_mod'],
#       dtype='object')
# (841, 20)

# %%
def file_to_entity(filename):
    return filename.replace('_directorio.csv','').replace('0_','').replace('.csv','')

global_cols = ['fecha_mod', 'gmaps_latitud', 'gmaps_longitud', 'nom_ent', 'nom_mun', 'nom_loc', 'email', 'pagina_web', 'estado_id', 'municipio_id', 'localidad_id', 'link_sic', 'fecha_fundacion']
global_sufixs = ['_id', '_nombre', '_calle_numero', '_colonia', '_pagina_web' , '_cp', '_telfono1', '_adscripcion', '_fecha_edicion', '_fecha_fundacion']
all_entities = []
for i, fpath in enumerate(all_paths):
    entity = file_to_entity(all_fns[i])
    sic_df = pd.read_csv(fpath, encoding = "ISO-8859-1")
    print(entity)
    sic_df = sic_df.reset_index()
    df_cols = list(sic_df.columns)
    for index, row in sic_df.iterrows():
        entity_dict = dict()
        entity_dict['type'] = entity
        entity_cols = []
        missing_cols = []
        for i, val in enumerate(row):
            field_name = df_cols[i]
            if entity in field_name:
                sfx_found = False
                for sfx in global_sufixs:
                    if sfx in field_name:
                        sfx_found = True
                        break
                if not sfx_found:
                    entity_cols.append(field_name)
                field_name = field_name.replace(entity, 'entity')
#             elif c in global_cols:
#                 continue
            else:
                missing_cols.append(field_name)
                
            if val:
                field_value = val
            else:
                field_value = None
            
            entity_dict[field_name] = field_value
        all_entities.append(entity_dict)
    if entity_cols:
        print(entity_cols)
    if missing_cols:
        print(missing_cols)
    print()
# Out:
# casa_artesania
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# patrimonio_humanidad
# ['patrimonio_humanidad_ano_inscripcion']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# centro_educacion
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'pagina_web', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# publicacion_dgcpi
# ['publicacion_dgcpi_titulo']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# grupo_etnico
# ['grupo_etnico_presentacion']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# institucion_cultural_mun
# ['index', 'fecha_fundacion', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'pagina_web', 'pagina_web2', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# fonoteca
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# fondo_editorial
# ['fondo_editorial_titulo', 'fondo_editorial_anno_edicion', 'fondo_editorial_autor_ap_pa', 'fondo_editorial_autor_ap_ma']
# ['index', 'email', 'link_sic', 'fecha_mod']
#
# zona_arqueologica
# ['zona_arqueologica_telefono1']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'pagina_web', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# galeria
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# teatro
# ['teatro_telefono1']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'pagina_web', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# centro_investigacion_artistica
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# radi
# ['radi_siglas', 'radi_frecuencia', 'radi_potencia', 'radi_podcast']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'pagina_web', 'pagina_web2', 'email', 'email2', 'link_sic', 'fecha_mod']
#
# institucion_cultural
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# museo
# ['museo_tematica_n1', 'museo_telefono1']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'pagina_web', 'pagina_web2', 'email', 'twitter', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# centro_desarrollo_indigena
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# fototeca
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# revista
# ['revista_disciplina', 'revista_clasificacion', 'revista_periodicidad', 'revista_issn']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'pagina_web', 'pagina_web2', 'email', 'email2', 'twitter', 'link_sic', 'fecha_mod']
#
# festividad
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# centro_cultural
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# frpintangible
# ['frpintangible_fechadec']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'link_sic', 'fecha_mod']
#
# convocatoria
# ['convocatoria_disciplina', 'convocatoria_genero', 'convocatoria_convocan', 'convocatoria_bases', 'convocatoria_premios', 'convocatoria_fecha_fin']
# ['index', 'nom_ent', 'nom_mun', 'pagina_web', 'email', 'link_sic', 'fecha_mod']
#
# festival
# ['festival_disciplina', 'festival_sede', 'festival_primera_emision', 'festival_fecha_inicio', 'festival_fecha_fin', 'festival_telfono2', 'festival_fax']
# ['index', 'pagina_web', 'email', 'link_sic', 'fecha_mod']
#
# educacion_artistica
# ['educacion_artistica_regimen']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'pagina_web', 'link_sic', 'fecha_mod']
#
# biblioteca
# ['biblioteca_numero_coleccion']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# libreria
# ['libreria_telefono1']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# otra_declaratoria
# ['otra_declaratoria_ano_inscripcion']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# universidad
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# catedral
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# revista_elec
# ['revista_elec_clasificacion']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'pagina_web', 'pagina_web2', 'email', 'email2', 'twitter', 'link_sic', 'fecha_mod']
#
# auditorio
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# fnme
# ['fnme_fecha2']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# otra_bib
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# discografica_dgcpi
# ['discografica_dgcpi_titulo', 'discografica_dgcpi_anno_edicion', 'discografica_dgcpi_descripcion', 'discografica_dgcpi_artista', 'discografica_dgcpi_produccion', 'discografica_dgcpi_temas']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# editorial
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'pagina_web', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# feria_libro
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# museo_analitico
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'cantidad_museos', 'pobtot', 'habxm', 'habxm2', 'habxm3', 'museo_por', 'fecha_calculo']
#
# impresos
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'email', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']
#
# comp_cine
# ['comp_cine_npantallas']
# ['index', 'estado_id', 'nom_ent', 'municipio_id', 'nom_mun', 'localidad_id', 'nom_loc', 'gmaps_longitud', 'gmaps_latitud', 'link_sic', 'fecha_mod']

# %%
print('total entidades en el pais:', len(all_entities))
# Out:
# total entidades en el pais: 37156

# %%
entities_df = pd.DataFrame(all_entities)

# %%
entities_df
# Out:
#                  type  index  entity_id  \
# 0      casa_artesania    NaN      222.0
# 1      casa_artesania    1.0      250.0
# 2      casa_artesania    2.0       34.0
# 3      casa_artesania    3.0       85.0
# 4      casa_artesania    4.0       29.0
# ...               ...    ...        ...
# 37151       comp_cine  836.0      422.0
# 37152       comp_cine  837.0      926.0
# 37153       comp_cine  838.0      423.0
# 37154       comp_cine  839.0      634.0
# 37155       comp_cine  840.0      908.0
#
#                                           entity_nombre  \
# 0                 Casa de las Artesanías Aguascalientes
# 1                                     Casa del Artesano
# 2      Casa de Artesanías del Centro de Artes y Oficios
# 3                     Casa del Artesano Sudcaliforniano
# 4                            Casa de Artesanías Tukulna
# ...                                                 ...
# 37151                                 Cinemex Fresnillo
# 37152                          Cinemex Portal Fresnillo
# 37153                                 Cinemex Zacatecas
# 37154                      Cinépolis Galerías Zacatecas
# 37155                                Cineteca Zacatecas
#
#                                       entity_adscripcion  estado_id  \
# 0                  Casa de las Artesanías Aguascalientes        1.0
# 1      Asociación de Artesanos y Manualidades de Agua...        1.0
# 2             Instituto Cultural de Aguascalientes (ICA)        1.0
# 3         Asociación de Artesanos Sudcalifornianos, A.C.        3.0
# 4                        Gobierno del Estado de Campeche        4.0
# ...                                                  ...        ...
# 37151        Cadena Mexicana de Exhibición, S.A. de C.V.       32.0
# 37152        Cadena Mexicana de Exhibición, S.A. de C.V.       32.0
# 37153        Cadena Mexicana de Exhibición, S.A. de C.V.       32.0
# 37154                  Cinépolis de México, S.A. de C.V.       32.0
# 37155  Instituto Zacatecano de Cultura Ramón López Ve...       32.0
#
#                    nom_ent  municipio_id         nom_mun  localidad_id  \
# 0           Aguascalientes           1.0  Aguascalientes           1.0
# 1           Aguascalientes           1.0  Aguascalientes           1.0
# 2           Aguascalientes           1.0  Aguascalientes           1.0
# 3      Baja California Sur           3.0          La Paz           1.0
# 4                 Campeche           2.0        Campeche           1.0
# ...                    ...           ...             ...           ...
# 37151            Zacatecas          10.0       Fresnillo           1.0
# 37152            Zacatecas          10.0       Fresnillo           1.0
# 37153            Zacatecas          56.0       Zacatecas           1.0
# 37154            Zacatecas          56.0       Zacatecas           1.0
# 37155            Zacatecas          56.0       Zacatecas           1.0
#
#                          nom_loc  \
# 0                 Aguascalientes
# 1                 Aguascalientes
# 2                 Aguascalientes
# 3                         La Paz
# 4      San Francisco de Campeche
# ...                          ...
# 37151                  Fresnillo
# 37152                  Fresnillo
# 37153                  Zacatecas
# 37154                  Zacatecas
# 37155                  Zacatecas
#
#                                      entity_calle_numero  \
# 0                                    Manuel M. Ponce 134
# 1                                              Nieto 210
# 2        Héroe de Nacozari 601 Nte. esq. Ventura Salazar
# 3      Av. Álvaro Obregón s/n entre Nicolás Bravo y R...
# 4                        Calle 10 núm. 333 entre 59 y 61
# ...                                                  ...
# 37151                      Francisco García Salinas 510
# 37152                                    Av. Sonora 1033
# 37153      Sevilla s/n esq. Av. Francisco García Salinas
# 37154                                  Blvd. El Bote 202
# 37155                           Fernando Villalpando 406
#
#                     entity_colonia entity_cp  entity_telfono1  \
# 0             Barrio de San Marcos   20070.0              NaN
# 1                           Centro   20000.0              NaN
# 2            Barrio de la Estación   20254.0              NaN
# 3                           Centro   23000.0              NaN
# 4                           Centro   24000.0              NaN
# ...                            ...       ...              ...
# 37151                       Centro     98097              NaN
# 37152  Col. Panamericana Fresnillo     99014              NaN
# 37153        Barrio Garcia Salinas     98018              NaN
# 37154              Ciudad Argentum     98040              NaN
# 37155                  Col. Centro     98000              NaN
#
#        entity_pagina_web                                              email  \
# 0                    NaN  casadelasartesaniasaguascalientesnex@gmail.com...
# 1                    NaN                             enzoluraschi@yahoo.com
# 2                    NaN                      artesyoficios1979@hotmail.com
# 3                    NaN                               casartsbcs@gmail.com
# 4                    NaN                 joselem.villanueva@campeche.gob.mx
# ...                  ...                                                ...
# 37151                NaN                                                NaN
# 37152                NaN                                                NaN
# 37153                NaN                                                NaN
# 37154                NaN                                                NaN
# 37155                NaN                                                NaN
#
#        gmaps_longitud  gmaps_latitud  \
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2          -102.28177       21.88286
# 3                 NaN            NaN
# 4                 NaN            NaN
# ...               ...            ...
# 37151      -102.86418       23.17314
# 37152      -102.88602       23.19412
# 37153      -102.54742       22.75809
# 37154      -102.59806       22.77686
# 37155      -102.57432       22.77516
#
#                                                 link_sic  \
# 0      http://sic.gob.mx/ficha.php?table=casa_artesan...
# 1      http://sic.gob.mx/ficha.php?table=casa_artesan...
# 2      http://sic.gob.mx/ficha.php?table=casa_artesan...
# 3      http://sic.gob.mx/ficha.php?table=casa_artesan...
# 4      http://sic.gob.mx/ficha.php?table=casa_artesan...
# ...                                                  ...
# 37151  http://sic.gob.mx/ficha.php?table=comp_cine&ta...
# 37152  http://sic.gob.mx/ficha.php?table=comp_cine&ta...
# 37153  http://sic.gob.mx/ficha.php?table=comp_cine&ta...
# 37154  http://sic.gob.mx/ficha.php?table=comp_cine&ta...
# 37155  http://sic.gob.mx/ficha.php?table=comp_cine&ta...
#
#                     fecha_mod  entity_ano_inscripcion pagina_web  \
# 0      2018-06-21 02:36:42-05                     NaN        NaN
# 1      2018-06-20 04:27:02-05                     NaN        NaN
# 2      2020-03-12 08:16:43-06                     NaN        NaN
# 3      2015-02-17 11:33:23-06                     NaN        NaN
# 4      2015-02-17 11:44:48-06                     NaN        NaN
# ...                       ...                     ...        ...
# 37151  2021-12-18 16:23:23-06                     NaN        NaN
# 37152  2021-04-08 12:36:40-05                     NaN        NaN
# 37153  2021-04-08 12:29:44-05                     NaN        NaN
# 37154  2020-12-10 05:16:42-06                     NaN        NaN
# 37155  2020-12-10 05:18:08-06                     NaN        NaN
#
#       entity_titulo  entity_fecha_edicion entity_presentacion fecha_fundacion  \
# 0               NaN                   NaN                 NaN             NaN
# 1               NaN                   NaN                 NaN             NaN
# 2               NaN                   NaN                 NaN             NaN
# 3               NaN                   NaN                 NaN             NaN
# 4               NaN                   NaN                 NaN             NaN
# ...             ...                   ...                 ...             ...
# 37151           NaN                   NaN                 NaN             NaN
# 37152           NaN                   NaN                 NaN             NaN
# 37153           NaN                   NaN                 NaN             NaN
# 37154           NaN                   NaN                 NaN             NaN
# 37155           NaN                   NaN                 NaN             NaN
#
#       pagina_web2 entity_anno_edicion entity_autor_nombre entity_autor_ap_pa  \
# 0             NaN                 NaN                 NaN                NaN
# 1             NaN                 NaN                 NaN                NaN
# 2             NaN                 NaN                 NaN                NaN
# 3             NaN                 NaN                 NaN                NaN
# 4             NaN                 NaN                 NaN                NaN
# ...           ...                 ...                 ...                ...
# 37151         NaN                 NaN                 NaN                NaN
# 37152         NaN                 NaN                 NaN                NaN
# 37153         NaN                 NaN                 NaN                NaN
# 37154         NaN                 NaN                 NaN                NaN
# 37155         NaN                 NaN                 NaN                NaN
#
#       entity_autor_ap_ma entity_telefono1 entity_fecha_fundacion  \
# 0                    NaN              NaN                    NaN
# 1                    NaN              NaN                    NaN
# 2                    NaN              NaN                    NaN
# 3                    NaN              NaN                    NaN
# 4                    NaN              NaN                    NaN
# ...                  ...              ...                    ...
# 37151                NaN              NaN             1000-01-01
# 37152                NaN              NaN             1000-01-01
# 37153                NaN              NaN             1000-01-01
# 37154                NaN              NaN             2014-12-01
# 37155                NaN              NaN             1000-01-01
#
#       entity_siglas entity_frecuencia entity_potencia entity_podcast email2  \
# 0               NaN               NaN             NaN            NaN    NaN
# 1               NaN               NaN             NaN            NaN    NaN
# 2               NaN               NaN             NaN            NaN    NaN
# 3               NaN               NaN             NaN            NaN    NaN
# 4               NaN               NaN             NaN            NaN    NaN
# ...             ...               ...             ...            ...    ...
# 37151           NaN               NaN             NaN            NaN    NaN
# 37152           NaN               NaN             NaN            NaN    NaN
# 37153           NaN               NaN             NaN            NaN    NaN
# 37154           NaN               NaN             NaN            NaN    NaN
# 37155           NaN               NaN             NaN            NaN    NaN
#
#       entity_tematica_n1 twitter entity_disciplina entity_clasificacion  \
# 0                    NaN     NaN               NaN                  NaN
# 1                    NaN     NaN               NaN                  NaN
# 2                    NaN     NaN               NaN                  NaN
# 3                    NaN     NaN               NaN                  NaN
# 4                    NaN     NaN               NaN                  NaN
# ...                  ...     ...               ...                  ...
# 37151                NaN     NaN               NaN                  NaN
# 37152                NaN     NaN               NaN                  NaN
# 37153                NaN     NaN               NaN                  NaN
# 37154                NaN     NaN               NaN                  NaN
# 37155                NaN     NaN               NaN                  NaN
#
#       entity_periodicidad entity_issn entity_fechadec entity_genero  \
# 0                     NaN         NaN             NaN           NaN
# 1                     NaN         NaN             NaN           NaN
# 2                     NaN         NaN             NaN           NaN
# 3                     NaN         NaN             NaN           NaN
# 4                     NaN         NaN             NaN           NaN
# ...                   ...         ...             ...           ...
# 37151                 NaN         NaN             NaN           NaN
# 37152                 NaN         NaN             NaN           NaN
# 37153                 NaN         NaN             NaN           NaN
# 37154                 NaN         NaN             NaN           NaN
# 37155                 NaN         NaN             NaN           NaN
#
#       entity_convocan entity_bases entity_premios entity_fecha_fin  \
# 0                 NaN          NaN            NaN              NaN
# 1                 NaN          NaN            NaN              NaN
# 2                 NaN          NaN            NaN              NaN
# 3                 NaN          NaN            NaN              NaN
# 4                 NaN          NaN            NaN              NaN
# ...               ...          ...            ...              ...
# 37151             NaN          NaN            NaN              NaN
# 37152             NaN          NaN            NaN              NaN
# 37153             NaN          NaN            NaN              NaN
# 37154             NaN          NaN            NaN              NaN
# 37155             NaN          NaN            NaN              NaN
#
#        entity_sede  entity_primera_emision  entity_fecha_inicio  \
# 0              NaN                     NaN                  NaN
# 1              NaN                     NaN                  NaN
# 2              NaN                     NaN                  NaN
# 3              NaN                     NaN                  NaN
# 4              NaN                     NaN                  NaN
# ...            ...                     ...                  ...
# 37151          NaN                     NaN                  NaN
# 37152          NaN                     NaN                  NaN
# 37153          NaN                     NaN                  NaN
# 37154          NaN                     NaN                  NaN
# 37155          NaN                     NaN                  NaN
#
#        entity_telfono2  entity_fax  entity_institucion_informate1_pagina_web  \
# 0                  NaN         NaN                                       NaN
# 1                  NaN         NaN                                       NaN
# 2                  NaN         NaN                                       NaN
# 3                  NaN         NaN                                       NaN
# 4                  NaN         NaN                                       NaN
# ...                ...         ...                                       ...
# 37151              NaN         NaN                                       NaN
# 37152              NaN         NaN                                       NaN
# 37153              NaN         NaN                                       NaN
# 37154              NaN         NaN                                       NaN
# 37155              NaN         NaN                                       NaN
#
#        entity_institucion_informate2_pagina_web entity_regimen  \
# 0                                           NaN            NaN
# 1                                           NaN            NaN
# 2                                           NaN            NaN
# 3                                           NaN            NaN
# 4                                           NaN            NaN
# ...                                         ...            ...
# 37151                                       NaN            NaN
# 37152                                       NaN            NaN
# 37153                                       NaN            NaN
# 37154                                       NaN            NaN
# 37155                                       NaN            NaN
#
#        entity_numero_coleccion entity_fecha2 entity_descripcion  \
# 0                          NaN           NaN                NaN
# 1                          NaN           NaN                NaN
# 2                          NaN           NaN                NaN
# 3                          NaN           NaN                NaN
# 4                          NaN           NaN                NaN
# ...                        ...           ...                ...
# 37151                      NaN           NaN                NaN
# 37152                      NaN           NaN                NaN
# 37153                      NaN           NaN                NaN
# 37154                      NaN           NaN                NaN
# 37155                      NaN           NaN                NaN
#
#        entity_artista entity_produccion entity_temas  cantidad_museos  pobtot  \
# 0                 NaN               NaN          NaN              NaN     NaN
# 1                 NaN               NaN          NaN              NaN     NaN
# 2                 NaN               NaN          NaN              NaN     NaN
# 3                 NaN               NaN          NaN              NaN     NaN
# 4                 NaN               NaN          NaN              NaN     NaN
# ...               ...               ...          ...              ...     ...
# 37151             NaN               NaN          NaN              NaN     NaN
# 37152             NaN               NaN          NaN              NaN     NaN
# 37153             NaN               NaN          NaN              NaN     NaN
# 37154             NaN               NaN          NaN              NaN     NaN
# 37155             NaN               NaN          NaN              NaN     NaN
#
#        habxm  habxm2  habxm3  museo_por fecha_calculo  entity_npantallas
# 0        NaN     NaN     NaN        NaN           NaN                NaN
# 1        NaN     NaN     NaN        NaN           NaN                NaN
# 2        NaN     NaN     NaN        NaN           NaN                NaN
# 3        NaN     NaN     NaN        NaN           NaN                NaN
# 4        NaN     NaN     NaN        NaN           NaN                NaN
# ...      ...     ...     ...        ...           ...                ...
# 37151    NaN     NaN     NaN        NaN           NaN                4.0
# 37152    NaN     NaN     NaN        NaN           NaN                NaN
# 37153    NaN     NaN     NaN        NaN           NaN               10.0
# 37154    NaN     NaN     NaN        NaN           NaN               12.0
# 37155    NaN     NaN     NaN        NaN           NaN                2.0
#
# [37156 rows x 73 columns]

# %%
integer_location = np.where(df.index == 3454)[0][0]
start = max(0, integer_location - 55)
end = max(1, integer_location)
dfRange = df.iloc[start:end]

# %%
geometry = [Point(xy) for xy in zip(entities_df['gmaps_longitud'], entities_df['gmaps_latitud'])]
gdf = GeoDataFrame(entities_df, geometry=geometry)   

#this is a simple map that goes with geopandas
# world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
mexico = gpd.read_file(data_dir.replace('sic', 'maps') + 'Curvas_Mexico/Curvas_Nivel_Mexico.shp')
gdf.plot(ax=mexico.to_crs(epsg=3857).plot(figsize=(10, 6)), marker='o', color='red', markersize=15);
